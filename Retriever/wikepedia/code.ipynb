# %% [markdown]
# ***Wikipedia***

# %%
# %pip install langchain chromadb faiss-cpu groq tiktoken langchain_groq langchain_community wikipedia
# Out:
# ...
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.2/18.2 MB 3.0 MB/s eta 0:00:00a 0:00:01
# ...
#   Created wheel for wikipedia: filename=wikipedia-1.4.0-py3-none-any.whl size=11756 sha256=41519d0da63e7197d9fb84f23a7cba0320b6e3bfe92ff36fe0f9179dd39d4e60
#   Stored in directory: /home/sandip/.cache/pip/wheels/30/24/d3/9d46daa49494cef2f32dc9a8f203aac1f10cec980adba03d1f
# Successfully built wikipedia
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [wikipedia]
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from langchain_community.retrievers import WikipediaRetriever

# %%
#setting lamgauge and top_k
retriver = WikipediaRetriever(top_k_results=2, lang='en')

# %%
query = 'Network address translation'

# %%
result = retriver.invoke(query)

# %%
result
# Out:
# [Document(metadata={'title': 'Network address translation', 'summary': "Network address translation (NAT) is a method of mapping an IP address space into another by modifying network address information in the IP header of packets while they are in transit across a traffic routing device.  The technique was initially used to bypass the need to assign a new address to every host when a network was moved, or when the upstream Internet service provider was replaced but could not route the network's address space. It is a popular and essential tool in conserving global address space in the face of IPv4 address exhaustion. One Internet-routable IP address of a NAT gateway can be used for an entire private network.\nAs network address translation modifies the IP address information in packets, NAT implementations may vary in their specific behavior in various addressing cases and their effect on network traffic. Vendors of equipment containing NAT implementations do not commonly document t
# ...
