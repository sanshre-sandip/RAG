# %% [markdown]
# **TEXT LOADERS**

# %%
# %pip install langchain
# Out:
# ...
#   Using cached langchain_core-1.4.0-py3-none-any.whl.metadata (4.5 kB)
# ...
#   Using cached pydantic-2.13.4-py3-none-any.whl.metadata (109 kB)
# ...
#   Using cached jsonpatch-1.33-py2.py3-none-any.whl.metadata (3.0 kB)
# ...
#   Using cached langchain_protocol-0.0.16-py3-none-any.whl.metadata (2.4 kB)
# ...
#   Using cached langsmith-0.8.8-py3-none-any.whl.metadata (15 kB)
# ...
#   Using cached pyyaml-6.0.3-cp314-cp314-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (2.4 kB)
# ...
#   Using cached tenacity-9.1.4-py3-none-any.whl.metadata (1.2 kB)
# ...
#   Using cached typing_extensions-4.15.0-py3-none-any.whl.metadata (3.3 kB)
# ...
#   Using cached uuid_utils-0.16.0-cp314-cp314-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.4 kB)
# ...
#   Using cached jsonpointer-3.1.1-py3-none-any.whl.metadata (2.4 kB)
# ...
#   Using cached langgraph_checkpoint-4.1.1-py3-none-any.whl.metadata (5.2 kB)
# ...
#   Using cached langgraph_prebuilt-1.1.0-py3-none-any.whl.metadata (5.2 kB)
# ...

# %%
# %pip install langchain_community
# Out:
# ...
#   Using cached numpy-2.4.6-cp314-cp314-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (6.6 kB)
# ...
#   Using cached pydantic_settings-2.14.1-py3-none-any.whl.metadata (3.4 kB)
# ...
#   Using cached sqlalchemy-2.0.50-cp314-cp314-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (9.5 kB)
# ...
#   Using cached aiohappyeyeballs-2.6.2-py3-none-any.whl.metadata (5.9 kB)
# ...
#   Using cached aiosignal-1.4.0-py3-none-any.whl.metadata (3.7 kB)
# ...
#   Using cached attrs-26.1.0-py3-none-any.whl.metadata (8.8 kB)
# ...
#   Using cached frozenlist-1.8.0-cp314-cp314-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl.metadata (20 kB)
# ...
#   Using cached multidict-6.7.1-cp314-cp314-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (5.3 kB)
# ...
#   Using cached propcache-0.5.2-cp314-cp314-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (16 kB)
# ...

# %%
from langchain_community.document_loaders import TextLoader
# Out:
# /tmp/ipykernel_22194/2929458509.py:1: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.document_loaders import TextLoader

# %%
loader = TextLoader('Newari_Culture.txt')

# %%
docs = loader.load()

# %%
print(docs)
# Out:
# [Document(metadata={'source': 'Newari_Culture.txt'}, page_content='Newari Culture\n\nNewari culture is the traditional culture of the Newar people, the\nindigenous inhabitants of the Kathmandu Valley in Nepal. It is one of\nthe richest and most influential cultural traditions in the country,\nknown for its unique language, festivals, architecture, cuisine, music,\ndance, and craftsmanship.\n\nLanguage\n\nThe Newar people traditionally speak Nepal Bhasa (Newari), a language\nwith a long literary history. It has been used in religious texts,\npoetry, and historical records for centuries.\n\nFestivals\n\nNewari culture is famous for colorful festivals, including: - Indra\nJatra - Bisket Jatra - Gai Jatra - Yenya Festival - Machhindranath Jatra\n\nThese festivals combine religious devotion, community participation,\nmusic, dance, and traditional processions.\n\nArchitecture and Art\n\nNewar artisans are renowned for their wood carving, metalwork, stone\nsculpture, and traditional archite
# ...

# %%
print(type(docs))
# Out:
# <class 'list'>

# %%
print(docs[-1].page_content)
# Out:
# Newari Culture
#
# Newari culture is the traditional culture of the Newar people, the
# indigenous inhabitants of the Kathmandu Valley in Nepal. It is one of
# the richest and most influential cultural traditions in the country,
# known for its unique language, festivals, architecture, cuisine, music,
# dance, and craftsmanship.
#
# Language
#
# The Newar people traditionally speak Nepal Bhasa (Newari), a language
# with a long literary history. It has been used in religious texts,
# poetry, and historical records for centuries.
#
# Festivals
#
# Newari culture is famous for colorful festivals, including: - Indra
# Jatra - Bisket Jatra - Gai Jatra - Yenya Festival - Machhindranath Jatra
#
# These festivals combine religious devotion, community participation,
# music, dance, and traditional processions.
#
# Architecture and Art
#
# Newar artisans are renowned for their wood carving, metalwork, stone
# sculpture, and traditional architecture. Many historic temples, palaces,
# ...

# %%
print(docs[0].metadata)
# Out:
# {'source': 'Newari_Culture.txt'}
