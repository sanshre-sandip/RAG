# %% [markdown]
# ***loading all types of file using directory loader***

# %%
# %pip install langchain-community pypdf python-docx unstructured
# %pip install markdown
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from langchain_community.document_loaders import DirectoryLoader, PyPDFLoader, TextLoader, Docx2txtLoader
from typing import List

# %%
loader = DirectoryLoader(
    "data",
    glob="**/*",
    use_multithreading=True
)

docs = list(loader.lazy_load())
print(docs[-1].metadata)
# Out:
# Error loading file data/Al.pdf
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[68], line 7
#       3     glob="**/*",
#       4     use_multithreading=True
#       5 )
#       6
# ----> 7 docs = list(loader.lazy_load())
#       8 print(docs[-1].metadata)
#
# File ~/RAG/rag/lib/python3.14/site-packages/langchain_community/document_loaders/directory.py:191, in DirectoryLoader.lazy_load(self)
#     182             futures.append(
#     183                 executor.submit(
#     184                     self._lazy_load_file_to_non_generator(self._lazy_load_file),
#    (...)    188                 )
#     189             )
#     190         for future in concurrent.futures.as_completed(futures):
# --> 191             for item in future.result():
#     192                 yield item
#     193 else:
#
# ...

# %%
print(docs[-1].page_content)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[65], line 1
# ----> 1 print(docs[-1].page_content)
#
# TypeError: 'generator' object is not subscriptable
