# %% [markdown]
# ***loading all types of file using directory loader***

# %%
from langchain_community.document_loaders import DirectoryLoader,PyPDFLoader
# Out:
# /tmp/ipykernel_46699/714825054.py:1: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.document_loaders import DirectoryLoader

# %%
loader = DirectoryLoader(
    path='data',
    glob='**/*.pdf'
)

# %%
# %pip install unstructured
# %pip install unstructured[local-inference]
# Out:
# Requirement already satisfied: unstructured in /home/sandip/RAG/rag/lib/python3.14/site-packages (0.18.32)
# Requirement already satisfied: charset-normalizer in /home/sandip/RAG/rag/lib/python3.14/site-packages (from unstructured) (3.4.7)
# Requirement already satisfied: filetype in /home/sandip/RAG/rag/lib/python3.14/site-packages (from unstructured) (1.2.0)
# Requirement already satisfied: python-magic in /home/sandip/RAG/rag/lib/python3.14/site-packages (from unstructured) (0.4.27)
# Requirement already satisfied: lxml in /home/sandip/RAG/rag/lib/python3.14/site-packages (from unstructured) (6.1.1)
# Requirement already satisfied: nltk in /home/sandip/RAG/rag/lib/python3.14/site-packages (from unstructured) (3.9.4)
# Requirement already satisfied: requests in /home/sandip/RAG/rag/lib/python3.14/site-packages (from unstructured) (2.34.2)
# Requirement already satisfied: beautifulsoup4 in /home/sandip/RAG/rag/lib/python3.14/site-packages (from unstructured) (4.14.3)
# Requirement already satisfied: emoji in /home/sandip/RAG/rag/lib/python3.14/site-packages (from unstructured) (2.15.0)
# Requirement already satisfied: dataclasses-json in /home/sandip/RAG/rag/lib/python3.14/site-packages (from unstructured) (0.6.7)
# Requirement already satisfied: python-iso639 in /home/sandip/RAG/rag/lib/python3.14/site-packages (from unstructured) (2026.4.20)
# Requirement already satisfied: langdetect in /home/sandip/RAG/rag/lib/python3.14/site-packages (from unstructured) (1.0.9)
# Requirement already satisfied: numpy in /home/sandip/RAG/rag/lib/python3.14/site-packages (from unstructured) (2.4.6)
# Requirement already satisfied: rapidfuzz in /home/sandip/RAG/rag/lib/python3.14/site-packages (from unstructured) (3.14.5)
# Requirement already satisfied: backoff in /home/sandip/RAG/rag/lib/python3.14/site-packages (from unstructured) (2.2.1)
# Requirement already satisfied: typing-extensions in /home/sandip/RAG/rag/lib/python3.14/site-packages (from unstructured) (4.15.0)
# Requirement already satisfied: unstructured-client in /home/sandip/RAG/rag/lib/python3.14/site-packages (from unstructured) (0.44.1)
# Requirement already satisfied: wrapt in /home/sandip/RAG/rag/lib/python3.14/site-packages (from unstructured) (2.2.1)
# Requirement already satisfied: tqdm in /home/sandip/RAG/rag/lib/python3.14/site-packages (from unstructured) (4.67.3)
# Requirement already satisfied: psutil in /home/sandip/RAG/rag/lib/python3.14/site-packages (from unstructured) (7.2.2)
# Requirement already satisfied: python-oxmsg in /home/sandip/RAG/rag/lib/python3.14/site-packages (from unstructured) (0.0.2)
# Requirement already satisfied: html5lib in /home/sandip/RAG/rag/lib/python3.14/site-packages (from unstructured) (1.1)
# Requirement already satisfied: numba in /home/sandip/RAG/rag/lib/python3.14/site-packages (from unstructured) (0.65.1)
# Requirement already satisfied: soupsieve>=1.6.1 in /home/sandip/RAG/rag/lib/python3.14/site-packages (from beautifulsoup4->unstructured) (2.8.4)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /home/sandip/RAG/rag/lib/python3.14/site-packages (from dataclasses-json->unstructured) (3.26.2)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /home/sandip/RAG/rag/lib/python3.14/site-packages (from dataclasses-json->unstructured) (0.9.0)
# Requirement already satisfied: packaging>=17.0 in /home/sandip/RAG/rag/lib/python3.14/site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->unstructured) (26.2)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /home/sandip/RAG/rag/lib/python3.14/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json->unstructured) (1.1.0)
# Requirement already satisfied: six>=1.9 in /home/sandip/RAG/rag/lib/python3.14/site-packages (from html5lib->unstructured) (1.17.0)
# Requirement already satisfied: webencodings in /home/sandip/RAG/rag/lib/python3.14/site-packages (from html5lib->unstructured) (0.5.1)
# Requirement already satisfied: click in /home/sandip/RAG/rag/lib/python3.14/site-packages (from nltk->unstructured) (8.4.1)
# Requirement already satisfied: joblib in /home/sandip/RAG/rag/lib/python3.14/site-packages (from nltk->unstructured) (1.5.3)
# Requirement already satisfied: regex>=2021.8.3 in /home/sandip/RAG/rag/lib/python3.14/site-packages (from nltk->unstructured) (2026.5.9)
# Requirement already satisfied: llvmlite<0.48,>=0.47.0dev0 in /home/sandip/RAG/rag/lib/python3.14/site-packages (from numba->unstructured) (0.47.0)
# Requirement already satisfied: olefile in /home/sandip/RAG/rag/lib/python3.14/site-packages (from python-oxmsg->unstructured) (0.47)
# Requirement already satisfied: idna<4,>=2.5 in /home/sandip/RAG/rag/lib/python3.14/site-packages (from requests->unstructured) (3.18)
# Requirement already satisfied: urllib3<3,>=1.26 in /home/sandip/RAG/rag/lib/python3.14/site-packages (from requests->unstructured) (2.7.0)
# Requirement already satisfied: certifi>=2023.5.7 in /home/sandip/RAG/rag/lib/python3.14/site-packages (from requests->unstructured) (2026.5.20)
# Requirement already satisfied: aiofiles>=25.1.0 in /home/sandip/RAG/rag/lib/python3.14/site-packages (from unstructured-client->unstructured) (25.1.0)
# Requirement already satisfied: httpcore>=1.0.9 in /home/sandip/RAG/rag/lib/python3.14/site-packages (from unstructured-client->unstructured) (1.0.9)
# Requirement already satisfied: httpx>=0.28.1 in /home/sandip/RAG/rag/lib/python3.14/site-packages (from unstructured-client->unstructured) (0.28.1)
# Requirement already satisfied: pydantic>=2.12.5 in /home/sandip/RAG/rag/lib/python3.14/site-packages (from unstructured-client->unstructured) (2.13.4)
# Requirement already satisfied: pypdf>=6.9.2 in /home/sandip/RAG/rag/lib/python3.14/site-packages (from unstructured-client->unstructured) (6.12.2)
# Requirement already satisfied: pypdfium2>=5.6.0 in /home/sandip/RAG/rag/lib/python3.14/site-packages (from unstructured-client->unstructured) (5.9.0)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /home/sandip/RAG/rag/lib/python3.14/site-packages (from unstructured-client->unstructured) (1.0.0)
# Requirement already satisfied: h11>=0.16 in /home/sandip/RAG/rag/lib/python3.14/site-packages (from httpcore>=1.0.9->unstructured-client->unstructured) (0.16.0)
# Requirement already satisfied: anyio in /home/sandip/RAG/rag/lib/python3.14/site-packages (from httpx>=0.28.1->unstructured-client->unstructured) (4.13.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/sandip/RAG/rag/lib/python3.14/site-packages (from pydantic>=2.12.5->unstructured-client->unstructured) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in /home/sandip/RAG/rag/lib/python3.14/site-packages (from pydantic>=2.12.5->unstructured-client->unstructured) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /home/sandip/RAG/rag/lib/python3.14/site-packages (from pydantic>=2.12.5->unstructured-client->unstructured) (0.4.2)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: unstructured[local-inference] in /home/sandip/RAG/rag/lib/python3.14/site-packages (0.18.32)
# Requirement already satisfied: charset-normalizer in /home/sandip/RAG/rag/lib/python3.14/site-packages (from unstructured[local-inference]) (3.4.7)
# Requirement already satisfied: filetype in /home/sandip/RAG/rag/lib/python3.14/site-packages (from unstructured[local-inference]) (1.2.0)
# Requirement already satisfied: python-magic in /home/sandip/RAG/rag/lib/python3.14/site-packages (from unstructured[local-inference]) (0.4.27)
# Requirement already satisfied: lxml in /home/sandip/RAG/rag/lib/python3.14/site-packages (from unstructured[local-inference]) (6.1.1)
# Requirement already satisfied: nltk in /home/sandip/RAG/rag/lib/python3.14/site-packages (from unstructured[local-inference]) (3.9.4)
# Requirement already satisfied: requests in /home/sandip/RAG/rag/lib/python3.14/site-packages (from unstructured[local-inference]) (2.34.2)
# Requirement already satisfied: beautifulsoup4 in /home/sandip/RAG/rag/lib/python3.14/site-packages (from unstructured[local-inference]) (4.14.3)
# Requirement already satisfied: emoji in /home/sandip/RAG/rag/lib/python3.14/site-packages (from unstructured[local-inference]) (2.15.0)
# Requirement already satisfied: dataclasses-json in /home/sandip/RAG/rag/lib/python3.14/site-packages (from unstructured[local-inference]) (0.6.7)
# Requirement already satisfied: python-iso639 in /home/sandip/RAG/rag/lib/python3.14/site-packages (from unstructured[local-inference]) (2026.4.20)
# Requirement already satisfied: langdetect in /home/sandip/RAG/rag/lib/python3.14/site-packages (from unstructured[local-inference]) (1.0.9)
# Requirement already satisfied: numpy in /home/sandip/RAG/rag/lib/python3.14/site-packages (from unstructured[local-inference]) (2.4.6)
# Requirement already satisfied: rapidfuzz in /home/sandip/RAG/rag/lib/python3.14/site-packages (from unstructured[local-inference]) (3.14.5)
# Requirement already satisfied: backoff in /home/sandip/RAG/rag/lib/python3.14/site-packages (from unstructured[local-inference]) (2.2.1)
# Requirement already satisfied: typing-extensions in /home/sandip/RAG/rag/lib/python3.14/site-packages (from unstructured[local-inference]) (4.15.0)
# Requirement already satisfied: unstructured-client in /home/sandip/RAG/rag/lib/python3.14/site-packages (from unstructured[local-inference]) (0.44.1)
# Requirement already satisfied: wrapt in /home/sandip/RAG/rag/lib/python3.14/site-packages (from unstructured[local-inference]) (2.2.1)
# Requirement already satisfied: tqdm in /home/sandip/RAG/rag/lib/python3.14/site-packages (from unstructured[local-inference]) (4.67.3)
# Requirement already satisfied: psutil in /home/sandip/RAG/rag/lib/python3.14/site-packages (from unstructured[local-inference]) (7.2.2)
# Requirement already satisfied: python-oxmsg in /home/sandip/RAG/rag/lib/python3.14/site-packages (from unstructured[local-inference]) (0.0.2)
# Requirement already satisfied: html5lib in /home/sandip/RAG/rag/lib/python3.14/site-packages (from unstructured[local-inference]) (1.1)
# Requirement already satisfied: numba in /home/sandip/RAG/rag/lib/python3.14/site-packages (from unstructured[local-inference]) (0.65.1)
# Collecting pandas (from unstructured[local-inference])
#   Downloading pandas-3.0.3-cp314-cp314-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (79 kB)
# Collecting onnxruntime>=1.19.0 (from unstructured[local-inference])
#   Downloading onnxruntime-1.26.0-cp314-cp314-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (5.3 kB)
# Collecting unstructured.pytesseract>=0.3.12 (from unstructured[local-inference])
#   Downloading unstructured.pytesseract-0.3.15-py3-none-any.whl.metadata (11 kB)
# Collecting markdown (from unstructured[local-inference])
#   Downloading markdown-3.10.2-py3-none-any.whl.metadata (5.1 kB)
# Collecting networkx (from unstructured[local-inference])
#   Using cached networkx-3.6.1-py3-none-any.whl.metadata (6.8 kB)
# Collecting pikepdf (from unstructured[local-inference])
#   Downloading pikepdf-10.7.2-cp314-abi3-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (10 kB)
# Collecting openpyxl (from unstructured[local-inference])
#   Downloading openpyxl-3.1.5-py2.py3-none-any.whl.metadata (2.5 kB)
# Collecting pdf2image (from unstructured[local-inference])
#   Downloading pdf2image-1.17.0-py3-none-any.whl.metadata (6.2 kB)
# Collecting pi_heif (from unstructured[local-inference])
#   Downloading pi_heif-1.3.0-cp314-cp314-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (6.3 kB)
# Collecting google-cloud-vision (from unstructured[local-inference])
#   Downloading google_cloud_vision-3.14.0-py3-none-any.whl.metadata (9.5 kB)
# Collecting msoffcrypto-tool (from unstructured[local-inference])
#   Downloading msoffcrypto_tool-6.0.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: pypdf in /home/sandip/RAG/rag/lib/python3.14/site-packages (from unstructured[local-inference]) (6.12.2)
# Collecting effdet (from unstructured[local-inference])
#   Downloading effdet-0.4.1-py3-none-any.whl.metadata (33 kB)
# Collecting pypandoc (from unstructured[local-inference])
#   Downloading pypandoc-1.17-py3-none-any.whl.metadata (18 kB)
# Collecting onnx>=1.17.0 (from unstructured[local-inference])
#   Downloading onnx-1.21.0-cp312-abi3-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (8.5 kB)
# Collecting python-pptx>=1.0.1 (from unstructured[local-inference])
#   Downloading python_pptx-1.0.2-py3-none-any.whl.metadata (2.5 kB)
# Collecting xlrd (from unstructured[local-inference])
#   Downloading xlrd-2.0.2-py2.py3-none-any.whl.metadata (3.5 kB)
# Collecting pdfminer.six (from unstructured[local-inference])
#   Downloading pdfminer_six-20260107-py3-none-any.whl.metadata (4.3 kB)
# Collecting unstructured-inference>=1.1.1 (from unstructured[local-inference])
#   Downloading unstructured_inference-1.2.0-py3-none-any.whl.metadata (5.5 kB)
# Collecting python-docx>=1.1.2 (from unstructured[local-inference])
#   Downloading python_docx-1.2.0-py3-none-any.whl.metadata (2.0 kB)
# Collecting protobuf>=4.25.1 (from onnx>=1.17.0->unstructured[local-inference])
#   Using cached protobuf-7.35.0-cp310-abi3-manylinux2014_x86_64.whl.metadata (595 bytes)
# Collecting ml_dtypes>=0.5.0 (from onnx>=1.17.0->unstructured[local-inference])
#   Downloading ml_dtypes-0.5.4-cp314-cp314-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (8.9 kB)
# Collecting flatbuffers (from onnxruntime>=1.19.0->unstructured[local-inference])
#   Using cached flatbuffers-25.12.19-py2.py3-none-any.whl.metadata (1.0 kB)
# Requirement already satisfied: packaging in /home/sandip/RAG/rag/lib/python3.14/site-packages (from onnxruntime>=1.19.0->unstructured[local-inference]) (26.2)
# Collecting Pillow>=3.3.2 (from python-pptx>=1.0.1->unstructured[local-inference])
#   Downloading pillow-12.2.0-cp314-cp314-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (8.8 kB)
# Collecting XlsxWriter>=0.5.7 (from python-pptx>=1.0.1->unstructured[local-inference])
#   Downloading xlsxwriter-3.2.9-py3-none-any.whl.metadata (2.7 kB)
# Collecting python-multipart (from unstructured-inference>=1.1.1->unstructured[local-inference])
#   Downloading python_multipart-0.0.30-py3-none-any.whl.metadata (2.1 kB)
# Collecting huggingface-hub (from unstructured-inference>=1.1.1->unstructured[local-inference])
#   Using cached huggingface_hub-1.17.0-py3-none-any.whl.metadata (14 kB)
# Collecting opencv-python>=4.13.0.90 (from unstructured-inference>=1.1.1->unstructured[local-inference])
#   Using cached opencv_python-4.13.0.92-cp37-abi3-manylinux_2_28_x86_64.whl.metadata (19 kB)
# Collecting matplotlib (from unstructured-inference>=1.1.1->unstructured[local-inference])
#   Downloading matplotlib-3.10.9-cp314-cp314-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (52 kB)
# Collecting torch (from unstructured-inference>=1.1.1->unstructured[local-inference])
#   Using cached torch-2.12.0-cp314-cp314-manylinux_2_28_x86_64.whl.metadata (31 kB)
# Collecting timm (from unstructured-inference>=1.1.1->unstructured[local-inference])
#   Downloading timm-1.0.27-py3-none-any.whl.metadata (40 kB)
# Collecting transformers>=4.25.1 (from unstructured-inference>=1.1.1->unstructured[local-inference])
#   Using cached transformers-5.9.0-py3-none-any.whl.metadata (33 kB)
# Collecting accelerate (from unstructured-inference>=1.1.1->unstructured[local-inference])
#   Using cached accelerate-1.13.0-py3-none-any.whl.metadata (19 kB)
# Collecting scipy (from unstructured-inference>=1.1.1->unstructured[local-inference])
#   Using cached scipy-1.17.1-cp314-cp314-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (62 kB)
# Requirement already satisfied: pypdfium2>=5.0.0 in /home/sandip/RAG/rag/lib/python3.14/site-packages (from unstructured-inference>=1.1.1->unstructured[local-inference]) (5.9.0)
# Requirement already satisfied: pyyaml>=5.1 in /home/sandip/RAG/rag/lib/python3.14/site-packages (from transformers>=4.25.1->unstructured-inference>=1.1.1->unstructured[local-inference]) (6.0.3)
# Requirement already satisfied: regex>=2025.10.22 in /home/sandip/RAG/rag/lib/python3.14/site-packages (from transformers>=4.25.1->unstructured-inference>=1.1.1->unstructured[local-inference]) (2026.5.9)
# Collecting tokenizers<=0.23.0,>=0.22.0 (from transformers>=4.25.1->unstructured-inference>=1.1.1->unstructured[local-inference])
#   Using cached tokenizers-0.22.2-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.3 kB)
# Collecting typer (from transformers>=4.25.1->unstructured-inference>=1.1.1->unstructured[local-inference])
#   Downloading typer-0.26.7-py3-none-any.whl.metadata (16 kB)
# Collecting safetensors>=0.4.3 (from transformers>=4.25.1->unstructured-inference>=1.1.1->unstructured[local-inference])
#   Using cached safetensors-0.7.0-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.1 kB)
# Requirement already satisfied: click>=8.4.0 in /home/sandip/RAG/rag/lib/python3.14/site-packages (from huggingface-hub->unstructured-inference>=1.1.1->unstructured[local-inference]) (8.4.1)
# Collecting filelock>=3.10.0 (from huggingface-hub->unstructured-inference>=1.1.1->unstructured[local-inference])
#   Using cached filelock-3.29.0-py3-none-any.whl.metadata (2.0 kB)
# Collecting fsspec>=2023.5.0 (from huggingface-hub->unstructured-inference>=1.1.1->unstructured[local-inference])
#   Using cached fsspec-2026.4.0-py3-none-any.whl.metadata (10 kB)
# Collecting hf-xet<2.0.0,>=1.4.3 (from huggingface-hub->unstructured-inference>=1.1.1->unstructured[local-inference])
#   Using cached hf_xet-1.5.0-cp37-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (4.9 kB)
# Requirement already satisfied: httpx<1,>=0.23.0 in /home/sandip/RAG/rag/lib/python3.14/site-packages (from huggingface-hub->unstructured-inference>=1.1.1->unstructured[local-inference]) (0.28.1)
# Collecting typer (from transformers>=4.25.1->unstructured-inference>=1.1.1->unstructured[local-inference])
#   Using cached typer-0.25.1-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: anyio in /home/sandip/RAG/rag/lib/python3.14/site-packages (from httpx<1,>=0.23.0->huggingface-hub->unstructured-inference>=1.1.1->unstructured[local-inference]) (4.13.0)
# Requirement already satisfied: certifi in /home/sandip/RAG/rag/lib/python3.14/site-packages (from httpx<1,>=0.23.0->huggingface-hub->unstructured-inference>=1.1.1->unstructured[local-inference]) (2026.5.20)
# Requirement already satisfied: httpcore==1.* in /home/sandip/RAG/rag/lib/python3.14/site-packages (from httpx<1,>=0.23.0->huggingface-hub->unstructured-inference>=1.1.1->unstructured[local-inference]) (1.0.9)
# Requirement already satisfied: idna in /home/sandip/RAG/rag/lib/python3.14/site-packages (from httpx<1,>=0.23.0->huggingface-hub->unstructured-inference>=1.1.1->unstructured[local-inference]) (3.18)
# Requirement already satisfied: h11>=0.16 in /home/sandip/RAG/rag/lib/python3.14/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub->unstructured-inference>=1.1.1->unstructured[local-inference]) (0.16.0)
# Collecting shellingham>=1.3.0 (from typer->transformers>=4.25.1->unstructured-inference>=1.1.1->unstructured[local-inference])
#   Using cached shellingham-1.5.4-py2.py3-none-any.whl.metadata (3.5 kB)
# Collecting rich>=13.8.0 (from typer->transformers>=4.25.1->unstructured-inference>=1.1.1->unstructured[local-inference])
#   Using cached rich-15.0.0-py3-none-any.whl.metadata (18 kB)
# Collecting annotated-doc>=0.0.2 (from typer->transformers>=4.25.1->unstructured-inference>=1.1.1->unstructured[local-inference])
#   Using cached annotated_doc-0.0.4-py3-none-any.whl.metadata (6.6 kB)
# Collecting markdown-it-py>=2.2.0 (from rich>=13.8.0->typer->transformers>=4.25.1->unstructured-inference>=1.1.1->unstructured[local-inference])
#   Using cached markdown_it_py-4.2.0-py3-none-any.whl.metadata (7.4 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/sandip/RAG/rag/lib/python3.14/site-packages (from rich>=13.8.0->typer->transformers>=4.25.1->unstructured-inference>=1.1.1->unstructured[local-inference]) (2.20.0)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich>=13.8.0->typer->transformers>=4.25.1->unstructured-inference>=1.1.1->unstructured[local-inference])
#   Using cached mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Collecting setuptools<82 (from torch->unstructured-inference>=1.1.1->unstructured[local-inference])
#   Using cached setuptools-81.0.0-py3-none-any.whl.metadata (6.6 kB)
# Collecting sympy>=1.13.3 (from torch->unstructured-inference>=1.1.1->unstructured[local-inference])
#   Using cached sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# Collecting jinja2 (from torch->unstructured-inference>=1.1.1->unstructured[local-inference])
#   Using cached jinja2-3.1.6-py3-none-any.whl.metadata (2.9 kB)
# Collecting cuda-toolkit==13.0.2 (from cuda-toolkit[cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch->unstructured-inference>=1.1.1->unstructured[local-inference])
#   Using cached cuda_toolkit-13.0.2-py2.py3-none-any.whl.metadata (9.4 kB)
# Collecting nvidia-cublas<=13.1.1.3,>=13.1.0.3 (from torch->unstructured-inference>=1.1.1->unstructured[local-inference])
#   Using cached nvidia_cublas-13.1.1.3-py3-none-manylinux_2_27_x86_64.whl.metadata (1.8 kB)
# Collecting cuda-bindings<14,>=13.0.3 (from torch->unstructured-inference>=1.1.1->unstructured[local-inference])
#   Downloading cuda_bindings-13.3.1-cp314-cp314-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (2.5 kB)
# Collecting nvidia-cudnn-cu13==9.20.0.48 (from torch->unstructured-inference>=1.1.1->unstructured[local-inference])
#   Using cached nvidia_cudnn_cu13-9.20.0.48-py3-none-manylinux_2_27_x86_64.whl.metadata (1.9 kB)
# Collecting nvidia-cusparselt-cu13==0.8.1 (from torch->unstructured-inference>=1.1.1->unstructured[local-inference])
#   Using cached nvidia_cusparselt_cu13-0.8.1-py3-none-manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting nvidia-nccl-cu13==2.29.7 (from torch->unstructured-inference>=1.1.1->unstructured[local-inference])
#   Using cached nvidia_nccl_cu13-2.29.7-py3-none-manylinux_2_18_x86_64.whl.metadata (2.1 kB)
# Collecting nvidia-nvshmem-cu13==3.4.5 (from torch->unstructured-inference>=1.1.1->unstructured[local-inference])
#   Using cached nvidia_nvshmem_cu13-3.4.5-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (2.1 kB)
# Collecting triton==3.7.0 (from torch->unstructured-inference>=1.1.1->unstructured[local-inference])
#   Using cached triton-3.7.0-cp314-cp314-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-cuda-runtime==13.0.96.* (from cuda-toolkit[cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch->unstructured-inference>=1.1.1->unstructured[local-inference])
#   Using cached nvidia_cuda_runtime-13.0.96-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-cufft==12.0.0.61.* (from cuda-toolkit[cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch->unstructured-inference>=1.1.1->unstructured[local-inference])
#   Using cached nvidia_cufft-12.0.0.61-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-cufile==1.15.1.6.* (from cuda-toolkit[cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch->unstructured-inference>=1.1.1->unstructured[local-inference])
#   Using cached nvidia_cufile-1.15.1.6-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-cuda-cupti==13.0.85.* (from cuda-toolkit[cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch->unstructured-inference>=1.1.1->unstructured[local-inference])
#   Using cached nvidia_cuda_cupti-13.0.85-py3-none-manylinux_2_25_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-curand==10.4.0.35.* (from cuda-toolkit[cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch->unstructured-inference>=1.1.1->unstructured[local-inference])
#   Using cached nvidia_curand-10.4.0.35-py3-none-manylinux_2_27_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-cusolver==12.0.4.66.* (from cuda-toolkit[cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch->unstructured-inference>=1.1.1->unstructured[local-inference])
#   Using cached nvidia_cusolver-12.0.4.66-py3-none-manylinux_2_27_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-cusparse==12.6.3.3.* (from cuda-toolkit[cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch->unstructured-inference>=1.1.1->unstructured[local-inference])
#   Using cached nvidia_cusparse-12.6.3.3-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-nvjitlink==13.0.88.* (from cuda-toolkit[cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch->unstructured-inference>=1.1.1->unstructured[local-inference])
#   Using cached nvidia_nvjitlink-13.0.88-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-cuda-nvrtc==13.0.88.* (from cuda-toolkit[cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch->unstructured-inference>=1.1.1->unstructured[local-inference])
#   Using cached nvidia_cuda_nvrtc-13.0.88-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-nvtx==13.0.85.* (from cuda-toolkit[cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch->unstructured-inference>=1.1.1->unstructured[local-inference])
#   Using cached nvidia_nvtx-13.0.85-py3-none-manylinux1_x86_64.manylinux_2_5_x86_64.whl.metadata (1.8 kB)
# Collecting cuda-pathfinder>=1.4.2 (from cuda-bindings<14,>=13.0.3->torch->unstructured-inference>=1.1.1->unstructured[local-inference])
#   Using cached cuda_pathfinder-1.5.5-py3-none-any.whl.metadata (1.9 kB)
# Collecting mpmath<1.4,>=1.1.0 (from sympy>=1.13.3->torch->unstructured-inference>=1.1.1->unstructured[local-inference])
#   Using cached mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Requirement already satisfied: soupsieve>=1.6.1 in /home/sandip/RAG/rag/lib/python3.14/site-packages (from beautifulsoup4->unstructured[local-inference]) (2.8.4)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /home/sandip/RAG/rag/lib/python3.14/site-packages (from dataclasses-json->unstructured[local-inference]) (3.26.2)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /home/sandip/RAG/rag/lib/python3.14/site-packages (from dataclasses-json->unstructured[local-inference]) (0.9.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /home/sandip/RAG/rag/lib/python3.14/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json->unstructured[local-inference]) (1.1.0)
# Collecting torchvision (from effdet->unstructured[local-inference])
#   Downloading torchvision-0.27.0-cp314-cp314-manylinux_2_28_x86_64.whl.metadata (5.5 kB)
# Collecting pycocotools>=2.0.2 (from effdet->unstructured[local-inference])
#   Downloading pycocotools-2.0.11-cp312-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (1.3 kB)
# Collecting omegaconf>=2.0 (from effdet->unstructured[local-inference])
#   Using cached omegaconf-2.3.0-py3-none-any.whl.metadata (3.9 kB)
# Collecting antlr4-python3-runtime==4.9.* (from omegaconf>=2.0->effdet->unstructured[local-inference])
#   Using cached antlr4-python3-runtime-4.9.3.tar.gz (117 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting google-api-core<3.0.0,>=2.11.0 (from google-api-core[grpc]<3.0.0,>=2.11.0->google-cloud-vision->unstructured[local-inference])
#   Using cached google_api_core-2.30.3-py3-none-any.whl.metadata (3.1 kB)
# Collecting google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1 (from google-cloud-vision->unstructured[local-inference])
#   Using cached google_auth-2.53.0-py3-none-any.whl.metadata (5.5 kB)
# Collecting grpcio<2.0.0,>=1.33.2 (from google-cloud-vision->unstructured[local-inference])
#   Downloading grpcio-1.81.0-cp314-cp314-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (3.7 kB)
# Collecting proto-plus<2.0.0,>=1.22.3 (from google-cloud-vision->unstructured[local-inference])
#   Using cached proto_plus-1.28.0-py3-none-any.whl.metadata (2.2 kB)
# Collecting googleapis-common-protos<2.0.0,>=1.63.2 (from google-api-core<3.0.0,>=2.11.0->google-api-core[grpc]<3.0.0,>=2.11.0->google-cloud-vision->unstructured[local-inference])
#   Using cached googleapis_common_protos-1.75.0-py3-none-any.whl.metadata (8.6 kB)
# Collecting grpcio-status<2.0.0,>=1.33.2 (from google-api-core[grpc]<3.0.0,>=2.11.0->google-cloud-vision->unstructured[local-inference])
#   Downloading grpcio_status-1.81.0-py3-none-any.whl.metadata (1.2 kB)
# Collecting pyasn1-modules>=0.2.1 (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-cloud-vision->unstructured[local-inference])
#   Using cached pyasn1_modules-0.4.2-py3-none-any.whl.metadata (3.5 kB)
# Collecting cryptography>=38.0.3 (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-cloud-vision->unstructured[local-inference])
#   Using cached cryptography-48.0.0-cp311-abi3-manylinux_2_34_x86_64.whl.metadata (4.3 kB)
# Requirement already satisfied: urllib3<3,>=1.26 in /home/sandip/RAG/rag/lib/python3.14/site-packages (from requests->unstructured[local-inference]) (2.7.0)
# Collecting cffi>=2.0.0 (from cryptography>=38.0.3->google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-cloud-vision->unstructured[local-inference])
#   Using cached cffi-2.0.0-cp314-cp314-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (2.6 kB)
# Collecting pycparser (from cffi>=2.0.0->cryptography>=38.0.3->google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-cloud-vision->unstructured[local-inference])
#   Using cached pycparser-3.0-py3-none-any.whl.metadata (8.2 kB)
# Collecting pyasn1<0.7.0,>=0.6.1 (from pyasn1-modules>=0.2.1->google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-cloud-vision->unstructured[local-inference])
#   Using cached pyasn1-0.6.3-py3-none-any.whl.metadata (8.4 kB)
# Requirement already satisfied: six>=1.9 in /home/sandip/RAG/rag/lib/python3.14/site-packages (from html5lib->unstructured[local-inference]) (1.17.0)
# Requirement already satisfied: webencodings in /home/sandip/RAG/rag/lib/python3.14/site-packages (from html5lib->unstructured[local-inference]) (0.5.1)
# Collecting MarkupSafe>=2.0 (from jinja2->torch->unstructured-inference>=1.1.1->unstructured[local-inference])
#   Using cached markupsafe-3.0.3-cp314-cp314-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (2.7 kB)
# Collecting contourpy>=1.0.1 (from matplotlib->unstructured-inference>=1.1.1->unstructured[local-inference])
#   Downloading contourpy-1.3.3-cp314-cp314-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib->unstructured-inference>=1.1.1->unstructured[local-inference])
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib->unstructured-inference>=1.1.1->unstructured[local-inference])
#   Downloading fonttools-4.63.0-cp314-cp314-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (118 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib->unstructured-inference>=1.1.1->unstructured[local-inference])
#   Downloading kiwisolver-1.5.0-cp314-cp314-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (5.1 kB)
# Collecting pyparsing>=3 (from matplotlib->unstructured-inference>=1.1.1->unstructured[local-inference])
#   Using cached pyparsing-3.3.2-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: python-dateutil>=2.7 in /home/sandip/RAG/rag/lib/python3.14/site-packages (from matplotlib->unstructured-inference>=1.1.1->unstructured[local-inference]) (2.9.0.post0)
# Requirement already satisfied: olefile>=0.46 in /home/sandip/RAG/rag/lib/python3.14/site-packages (from msoffcrypto-tool->unstructured[local-inference]) (0.47)
# Requirement already satisfied: joblib in /home/sandip/RAG/rag/lib/python3.14/site-packages (from nltk->unstructured[local-inference]) (1.5.3)
# Requirement already satisfied: llvmlite<0.48,>=0.47.0dev0 in /home/sandip/RAG/rag/lib/python3.14/site-packages (from numba->unstructured[local-inference]) (0.47.0)
# Collecting et-xmlfile (from openpyxl->unstructured[local-inference])
#   Downloading et_xmlfile-2.0.0-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: aiofiles>=25.1.0 in /home/sandip/RAG/rag/lib/python3.14/site-packages (from unstructured-client->unstructured[local-inference]) (25.1.0)
# Requirement already satisfied: pydantic>=2.12.5 in /home/sandip/RAG/rag/lib/python3.14/site-packages (from unstructured-client->unstructured[local-inference]) (2.13.4)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /home/sandip/RAG/rag/lib/python3.14/site-packages (from unstructured-client->unstructured[local-inference]) (1.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/sandip/RAG/rag/lib/python3.14/site-packages (from pydantic>=2.12.5->unstructured-client->unstructured[local-inference]) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in /home/sandip/RAG/rag/lib/python3.14/site-packages (from pydantic>=2.12.5->unstructured-client->unstructured[local-inference]) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /home/sandip/RAG/rag/lib/python3.14/site-packages (from pydantic>=2.12.5->unstructured-client->unstructured[local-inference]) (0.4.2)
# Downloading onnx-1.21.0-cp312-abi3-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (17.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.6/17.6 MB 11.4 MB/s eta 0:00:00a 0:00:01
# Downloading ml_dtypes-0.5.4-cp314-cp314-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (5.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.0/5.0 MB 10.9 MB/s eta 0:00:00a 0:00:01
# Downloading onnxruntime-1.26.0-cp314-cp314-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (18.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.2/18.2 MB 10.9 MB/s eta 0:00:0000:0100:01
# Using cached protobuf-7.35.0-cp310-abi3-manylinux2014_x86_64.whl (327 kB)
# Downloading python_docx-1.2.0-py3-none-any.whl (252 kB)
# Downloading python_pptx-1.0.2-py3-none-any.whl (472 kB)
# Downloading pillow-12.2.0-cp314-cp314-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (7.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.1/7.1 MB 10.9 MB/s eta 0:00:00a 0:00:01
# Downloading unstructured_inference-1.2.0-py3-none-any.whl (49 kB)
# Using cached opencv_python-4.13.0.92-cp37-abi3-manylinux_2_28_x86_64.whl (72.9 MB)
# Using cached transformers-5.9.0-py3-none-any.whl (10.8 MB)
# Using cached huggingface_hub-1.17.0-py3-none-any.whl (671 kB)
# Using cached hf_xet-1.5.0-cp37-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (4.5 MB)
# Using cached tokenizers-0.22.2-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.3 MB)
# Using cached typer-0.25.1-py3-none-any.whl (58 kB)
# Using cached annotated_doc-0.0.4-py3-none-any.whl (5.3 kB)
# Using cached filelock-3.29.0-py3-none-any.whl (39 kB)
# Using cached fsspec-2026.4.0-py3-none-any.whl (203 kB)
# Using cached rich-15.0.0-py3-none-any.whl (310 kB)
# Using cached markdown_it_py-4.2.0-py3-none-any.whl (91 kB)
# Using cached mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Using cached safetensors-0.7.0-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (507 kB)
# Using cached shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Downloading unstructured.pytesseract-0.3.15-py3-none-any.whl (14 kB)
# Downloading xlsxwriter-3.2.9-py3-none-any.whl (175 kB)
# Using cached accelerate-1.13.0-py3-none-any.whl (383 kB)
# Using cached torch-2.12.0-cp314-cp314-manylinux_2_28_x86_64.whl (532.3 MB)
# Using cached cuda_toolkit-13.0.2-py2.py3-none-any.whl (2.4 kB)
# Using cached nvidia_cudnn_cu13-9.20.0.48-py3-none-manylinux_2_27_x86_64.whl (366.2 MB)
# Using cached nvidia_cusparselt_cu13-0.8.1-py3-none-manylinux2014_x86_64.whl (170.1 MB)
# Using cached nvidia_nccl_cu13-2.29.7-py3-none-manylinux_2_18_x86_64.whl (206.0 MB)
# Using cached nvidia_nvshmem_cu13-3.4.5-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (60.4 MB)
# Using cached triton-3.7.0-cp314-cp314-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (201.5 MB)
# Downloading cuda_bindings-13.3.1-cp314-cp314-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (6.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.5/6.5 MB 9.4 MB/s eta 0:00:00a 0:00:01m
# Using cached nvidia_cublas-13.1.1.3-py3-none-manylinux_2_27_x86_64.whl (423.1 MB)
# Using cached nvidia_cuda_cupti-13.0.85-py3-none-manylinux_2_25_x86_64.whl (10.7 MB)
# Using cached nvidia_cuda_nvrtc-13.0.88-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl (90.2 MB)
# Using cached nvidia_cuda_runtime-13.0.96-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (2.2 MB)
# Using cached nvidia_cufft-12.0.0.61-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (214.1 MB)
# Using cached nvidia_cufile-1.15.1.6-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (1.2 MB)
# Using cached nvidia_curand-10.4.0.35-py3-none-manylinux_2_27_x86_64.whl (59.5 MB)
# Using cached nvidia_cusolver-12.0.4.66-py3-none-manylinux_2_27_x86_64.whl (200.9 MB)
# Using cached nvidia_cusparse-12.6.3.3-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (145.9 MB)
# Using cached nvidia_nvjitlink-13.0.88-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl (40.7 MB)
# Using cached nvidia_nvtx-13.0.85-py3-none-manylinux1_x86_64.manylinux_2_5_x86_64.whl (148 kB)
# Using cached setuptools-81.0.0-py3-none-any.whl (1.1 MB)
# Using cached cuda_pathfinder-1.5.5-py3-none-any.whl (51 kB)
# Using cached networkx-3.6.1-py3-none-any.whl (2.1 MB)
# Using cached sympy-1.14.0-py3-none-any.whl (6.3 MB)
# Using cached mpmath-1.3.0-py3-none-any.whl (536 kB)
# Downloading effdet-0.4.1-py3-none-any.whl (112 kB)
# Using cached omegaconf-2.3.0-py3-none-any.whl (79 kB)
# Downloading pycocotools-2.0.11-cp312-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (411 kB)
# Downloading timm-1.0.27-py3-none-any.whl (2.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.6/2.6 MB 8.5 MB/s eta 0:00:00a 0:00:01
# Using cached flatbuffers-25.12.19-py2.py3-none-any.whl (26 kB)
# Downloading google_cloud_vision-3.14.0-py3-none-any.whl (543 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 543.1/543.1 kB 11.2 MB/s eta 0:00:00
# Using cached google_api_core-2.30.3-py3-none-any.whl (173 kB)
# Using cached google_auth-2.53.0-py3-none-any.whl (246 kB)
# Using cached googleapis_common_protos-1.75.0-py3-none-any.whl (300 kB)
# Downloading grpcio-1.81.0-cp314-cp314-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (6.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.8/6.8 MB 9.2 MB/s eta 0:00:00a 0:00:01m
# Downloading grpcio_status-1.81.0-py3-none-any.whl (14 kB)
# Using cached proto_plus-1.28.0-py3-none-any.whl (50 kB)
# Using cached cryptography-48.0.0-cp311-abi3-manylinux_2_34_x86_64.whl (4.7 MB)
# Using cached cffi-2.0.0-cp314-cp314-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (219 kB)
# Using cached pyasn1_modules-0.4.2-py3-none-any.whl (181 kB)
# Using cached pyasn1-0.6.3-py3-none-any.whl (83 kB)
# Using cached jinja2-3.1.6-py3-none-any.whl (134 kB)
# Using cached markupsafe-3.0.3-cp314-cp314-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (23 kB)
# Downloading markdown-3.10.2-py3-none-any.whl (108 kB)
# Downloading matplotlib-3.10.9-cp314-cp314-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (9.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 8.1 MB/s eta 0:00:0000:0100:01
# Downloading contourpy-1.3.3-cp314-cp314-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (363 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.63.0-cp314-cp314-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (4.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 6.9 MB/s eta 0:00:00a 0:00:01
# Downloading kiwisolver-1.5.0-cp314-cp314-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (1.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 5.8 MB/s eta 0:00:00a 0:00:01
# Using cached pyparsing-3.3.2-py3-none-any.whl (122 kB)
# Downloading msoffcrypto_tool-6.0.0-py3-none-any.whl (48 kB)
# Downloading openpyxl-3.1.5-py2.py3-none-any.whl (250 kB)
# Downloading et_xmlfile-2.0.0-py3-none-any.whl (18 kB)
# Downloading pandas-3.0.3-cp314-cp314-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (10.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.9/10.9 MB 5.8 MB/s eta 0:00:0000:010:01
# Downloading pdf2image-1.17.0-py3-none-any.whl (11 kB)
# Downloading pdfminer_six-20260107-py3-none-any.whl (6.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 6.4 MB/s eta 0:00:0000:0100:01
# Downloading pi_heif-1.3.0-cp314-cp314-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (1.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 5.8 MB/s eta 0:00:00a 0:00:01
# Downloading pikepdf-10.7.2-cp314-abi3-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 5.3 MB/s eta 0:00:00a 0:00:01
# Using cached pycparser-3.0-py3-none-any.whl (48 kB)
# Downloading pypandoc-1.17-py3-none-any.whl (23 kB)
# Downloading python_multipart-0.0.30-py3-none-any.whl (29 kB)
# Using cached scipy-1.17.1-cp314-cp314-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (35.2 MB)
# Downloading torchvision-0.27.0-cp314-cp314-manylinux_2_28_x86_64.whl (7.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 5.3 MB/s eta 0:00:00a 0:00:01
# Downloading xlrd-2.0.2-py2.py3-none-any.whl (96 kB)
# Building wheels for collected packages: antlr4-python3-runtime
#   Building wheel for antlr4-python3-runtime (pyproject.toml) ... done
#   Created wheel for antlr4-python3-runtime: filename=antlr4_python3_runtime-4.9.3-py3-none-any.whl size=144590 sha256=c6d18c63ccb71d434b49c39a83181eb1b07ae8011727c85fed6084e397c6e783
#   Stored in directory: /home/sandip/.cache/pip/wheels/ea/ca/a6/5ad163e6c66e23b25d4e6a81dba06bce77047ef6257d643728
# Successfully built antlr4-python3-runtime
# Installing collected packages: nvidia-cusparselt-cu13, mpmath, flatbuffers, cuda-toolkit, antlr4-python3-runtime, XlsxWriter, xlrd, triton, sympy, shellingham, setuptools, scipy, safetensors, python-multipart, python-docx, pyparsing, pypandoc, pycparser, pycocotools, pyasn1, protobuf, Pillow, opencv-python, omegaconf, nvidia-nvtx, nvidia-nvshmem-cu13, nvidia-nvjitlink, nvidia-nccl-cu13, nvidia-curand, nvidia-cufile, nvidia-cuda-runtime, nvidia-cuda-nvrtc, nvidia-cuda-cupti, networkx, ml_dtypes, mdurl, MarkupSafe, markdown, kiwisolver, hf-xet, grpcio, fsspec, fonttools, filelock, et-xmlfile, cycler, cuda-pathfinder, contourpy, annotated-doc, unstructured.pytesseract, python-pptx, pyasn1-modules, proto-plus, pikepdf, pi_heif, pdf2image, pandas, openpyxl, onnxruntime, onnx, nvidia-cusparse, nvidia-cufft, nvidia-cublas, matplotlib, markdown-it-py, jinja2, googleapis-common-protos, cuda-bindings, cffi, rich, nvidia-cusolver, nvidia-cudnn-cu13, grpcio-status, cryptography, typer, pdfminer.six, msoffcrypto-tool, google-auth, torch, huggingface-hub, google-api-core, torchvision, tokenizers, accelerate, transformers, timm, google-cloud-vision, unstructured-inference, effdet
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89/89 [effdet]86/89 [google-cloud-vision]
# Successfully installed MarkupSafe-3.0.3 Pillow-12.2.0 XlsxWriter-3.2.9 accelerate-1.13.0 annotated-doc-0.0.4 antlr4-python3-runtime-4.9.3 cffi-2.0.0 contourpy-1.3.3 cryptography-48.0.0 cuda-bindings-13.3.1 cuda-pathfinder-1.5.5 cuda-toolkit-13.0.2 cycler-0.12.1 effdet-0.4.1 et-xmlfile-2.0.0 filelock-3.29.0 flatbuffers-25.12.19 fonttools-4.63.0 fsspec-2026.4.0 google-api-core-2.30.3 google-auth-2.53.0 google-cloud-vision-3.14.0 googleapis-common-protos-1.75.0 grpcio-1.81.0 grpcio-status-1.81.0 hf-xet-1.5.0 huggingface-hub-1.17.0 jinja2-3.1.6 kiwisolver-1.5.0 markdown-3.10.2 markdown-it-py-4.2.0 matplotlib-3.10.9 mdurl-0.1.2 ml_dtypes-0.5.4 mpmath-1.3.0 msoffcrypto-tool-6.0.0 networkx-3.6.1 nvidia-cublas-13.1.1.3 nvidia-cuda-cupti-13.0.85 nvidia-cuda-nvrtc-13.0.88 nvidia-cuda-runtime-13.0.96 nvidia-cudnn-cu13-9.20.0.48 nvidia-cufft-12.0.0.61 nvidia-cufile-1.15.1.6 nvidia-curand-10.4.0.35 nvidia-cusolver-12.0.4.66 nvidia-cusparse-12.6.3.3 nvidia-cusparselt-cu13-0.8.1 nvidia-nccl-cu13-2.29.7 nvidia-nvjitlink-13.0.88 nvidia-nvshmem-cu13-3.4.5 nvidia-nvtx-13.0.85 omegaconf-2.3.0 onnx-1.21.0 onnxruntime-1.26.0 opencv-python-4.13.0.92 openpyxl-3.1.5 pandas-3.0.3 pdf2image-1.17.0 pdfminer.six-20260107 pi_heif-1.3.0 pikepdf-10.7.2 proto-plus-1.28.0 protobuf-7.35.0 pyasn1-0.6.3 pyasn1-modules-0.4.2 pycocotools-2.0.11 pycparser-3.0 pypandoc-1.17 pyparsing-3.3.2 python-docx-1.2.0 python-multipart-0.0.30 python-pptx-1.0.2 rich-15.0.0 safetensors-0.7.0 scipy-1.17.1 setuptools-81.0.0 shellingham-1.5.4 sympy-1.14.0 timm-1.0.27 tokenizers-0.22.2 torch-2.12.0 torchvision-0.27.0 transformers-5.9.0 triton-3.7.0 typer-0.25.1 unstructured-inference-1.2.0 unstructured.pytesseract-0.3.15 xlrd-2.0.2
# Note: you may need to restart the kernel to use updated packages.

# %%
docs = loader.load()
# Out:
# Error loading file data/Al.pdf
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 docs = loader.load()
#
# File ~/RAG/rag/lib/python3.14/site-packages/langchain_community/document_loaders/directory.py:117, in DirectoryLoader.load(self)
#     115 def load(self) -> List[Document]:
#     116     """Load documents."""
# --> 117     return list(self.lazy_load())
#
# File ~/RAG/rag/lib/python3.14/site-packages/langchain_community/document_loaders/directory.py:195, in DirectoryLoader.lazy_load(self)
#     193 else:
#     194     for i in items:
# --> 195         yield from self._lazy_load_file(i, p, pbar)
#     197 if pbar:
#     198     pbar.close()
#
# File ~/RAG/rag/lib/python3.14/site-packages/langchain_community/document_loaders/directory.py:233, in DirectoryLoader._lazy_load_file(self, item, path, pbar)
#     231     else:
#     232         logger.error(f"Error loading file {str(item)}")
# --> 233         raise e
#     234 finally:
#     235     if pbar:
#
# File ~/RAG/rag/lib/python3.14/site-packages/langchain_community/document_loaders/directory.py:223, in DirectoryLoader._lazy_load_file(self, item, path, pbar)
#     221 loader = self.loader_cls(str(item), **self.loader_kwargs)
#     222 try:
# --> 223     for subdoc in loader.lazy_load():
#     224         yield subdoc
#     225 except NotImplementedError:
#
# File ~/RAG/rag/lib/python3.14/site-packages/langchain_community/document_loaders/unstructured.py:107, in UnstructuredBaseLoader.lazy_load(self)
#     105 def lazy_load(self) -> Iterator[Document]:
#     106     """Load file."""
# --> 107     elements = self._get_elements()
#     108     self._post_process_elements(elements)
#     109     if self.mode == "elements":
#
# File ~/RAG/rag/lib/python3.14/site-packages/langchain_community/document_loaders/unstructured.py:228, in UnstructuredFileLoader._get_elements(self)
#     226 if isinstance(self.file_path, Path):
#     227     self.file_path = str(self.file_path)
# --> 228 return partition(filename=self.file_path, **self.unstructured_kwargs)
#
# File ~/RAG/rag/lib/python3.14/site-packages/unstructured/partition/auto.py:211, in partition(filename, file, encoding, content_type, url, headers, ssl_verify, request_timeout, strategy, skip_infer_table_types, ocr_languages, languages, detect_language_per_element, pdf_infer_table_structure, extract_images_in_pdf, extract_image_block_types, extract_image_block_output_dir, extract_image_block_to_payload, data_source_metadata, metadata_filename, hi_res_model_name, model_name, starting_page_number, **kwargs)
#     208 # -- handle PDF/Image partitioning separately because they have a lot of special-case
#     209 # -- parameters. We'll come back to this after sorting out the other file types.
#     210 if file_type == FileType.PDF:
# --> 211     partition_pdf = partitioner_loader.get(file_type)
#     212     elements = partition_pdf(
#     213         filename=filename,
#     214         file=file,
#    (...)    226         **kwargs,
#     227     )
#     228     return augment_metadata(elements)
#
# File ~/RAG/rag/lib/python3.14/site-packages/unstructured/partition/auto.py:364, in _PartitionerLoader.get(self, file_type)
#     361 # -- if the partitioner is not in the cache, load it; note this raises if one or more of
#     362 # -- the partitioner's dependencies is not installed.
#     363 if file_type not in self._partitioners:
# --> 364     self._partitioners[file_type] = self._load_partitioner(file_type)
#     366 return self._partitioners[file_type]
#
# File ~/RAG/rag/lib/python3.14/site-packages/unstructured/partition/auto.py:373, in _PartitionerLoader._load_partitioner(self, file_type)
#     371 for pkg_name in file_type.importable_package_dependencies:
#     372     if not dependency_exists(pkg_name):
# --> 373         raise ImportError(
#     374             f"{file_type.partitioner_function_name}() is not available because one or"
#     375             f" more dependencies are not installed. Use:"
#     376             f' pip install "unstructured[{file_type.extra_name}]" (including quotes)'
#     377             f" to install the required dependencies",
#     378         )
#     380 # -- load the partitioner and return it --
#     381 assert file_type.is_partitionable  # -- would be a programming error if this failed --
#
# ImportError: partition_pdf() is not available because one or more dependencies are not installed. Use: pip install "unstructured[pdf]" (including quotes) to install the required dependencies
